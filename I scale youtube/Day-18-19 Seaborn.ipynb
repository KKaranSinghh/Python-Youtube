# %% [markdown]
# ## Seaborn Library
# ##### Seaborn is a library for making statistical graph in python. it builds on top of matplotlib and integrates closely with pandas data structures.
# ##### seaborn helps you explore and understand your data. its plotting functions operate on dataframe and arrays containing whole datasets and internally perform the mapping and statistical aggregation to produce informative plots.
# ##### Different categories of plot in seaborn:-
# ##### Plots are basically used for visualizing the relationship between variables. Those variables can be either completely numerical or a category like a group, class, or division. Seaborn divides the plot into the below categories:-
# - Relational plots :- This plot is used to understand the relation between two variables.
# - Categorical plots :- This plot deals with categorical variables and how they can be visualized.
# - Distribution plots :- This plot is used for examining univariate and bivariate distributions.
# - Regression plots :- The regression plots in Seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses.
# - Matrix plots :- A matrix plot is an array of scatterplots.
# - Multi-plot grids :- It is a useful approach to draw multiple instances of the same data but different subsets of the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
var= [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

# %%
# Graph by matplotlib library to see difference with seaborn library

plt.plot(var, var1)
plt.show()

# %%
# same graph by seaborn library

var= [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

sns.lineplot(x=var, y=var1)
plt.show()

# %%
var= [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

# by using pandas library and seaborn library
df= pd.DataFrame({"var":var, "var1":var1}) 
sns.lineplot(x= 'var', y= 'var1', data=df)
plt.show()

# %%
var= [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

# by using pandas library
df= pd.DataFrame({"var":var, "var1":var1}) 
df
# Out:
#    var  var1
# 0    1     8
# 1    2     7
# 2    3     6
# 3    4     5
# 4    5     4
# 5    6     3
# 6    7     2
# 7    8     1

# %%
var= [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

# by using pandas library and seaborn library
df= pd.DataFrame({"var":var, "var1":var1}) 
sns.lineplot(x= 'var', y= 'var1', data=df)
plt.show()

# %%
df1= sns.load_dataset('penguins')
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x= 'bill_length_mm', y= 'flipper_length_mm', data=df1)
plt.show()

# %%
sns.lineplot(x= 'bill_length_mm', y= 'flipper_length_mm', data= df1, hue= 'sex')
plt.show()

# %%
sns.lineplot(x= 'bill_length_mm', y= 'flipper_length_mm', data= df1, hue= 'sex', style= 'sex',
             palette='rocket_r', markers= ['o', '>'])
plt.show()

# %%
# (head) to select data from dataset

df1= sns.load_dataset('penguins')#.head(20)
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x= 'bill_length_mm', y= 'flipper_length_mm', data= df1, hue= 'sex', style= 'sex',
             palette='rocket_r', markers= ['o', '>'])
plt.title('This is a line graph related to penguins')
plt.grid()  # for grid line
plt.show()

# %%
df1['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
# Bar plot

sns.barplot(x= df1.island, y= df1.bill_length_mm)
plt.show()

# %%
# another method for bar plot

sns.barplot(x= 'island', y= 'bill_length_mm', data= df1)
plt.show()

# %%
sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, hue= 'sex')
plt.show()

# %% [markdown]
# ### Order Parameter

# %%
order1= ['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, hue= 'sex', order= order1)
plt.show()

# %%
# Change hue order

order1= ['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, hue= 'sex', 
            order= order1, hue_order= ['Female','Male'])
plt.show()

# %%
# Default colors

order1= ['Dream','Torgersen','Biscoe']
sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, color= 'pink')
plt.show()

# %%
# Palette colors --> Accent, gist, prism, gist_earth

sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, hue= 'sex', palette= 'gist_earth')
plt.show()

# %%
# Saturation parameter for color grading

sns.barplot(x= 'island', y= 'bill_length_mm', data= df1, hue= 'sex', 
            palette= 'gist_earth', saturation= 0.3)
plt.show()

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# histogram in seaborn library

sns.displot(df1['flipper_length_mm'])
plt.show()

# %%
# bins Parameter --> for proper sequencing

sns.displot(df1['flipper_length_mm'], bins= [170,180,190,200,210,220,230,240])
plt.show()

# %%
# color parameter in histogram

sns.displot(df1['flipper_length_mm'], bins= [170,180,190,200,210,220,230,240], color='skyblue')
plt.show()

# %%
# kde (kernal dencity)

sns.displot(df1['flipper_length_mm'], bins= [170,180,190,200,210,220,230,240], color= 'red', kde= True)
plt.show()
